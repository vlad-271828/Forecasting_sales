# %% [markdown]
# # Sales

# %%
import pandas as pd
from IPython.display import display_html

sales = pd.read_csv('../../data/initial_data/ps_stats_initial.csv', parse_dates=['created', 'cut_time'])

# %%
sales
# Out:
#               id                    created                cut_time film_size  \
# 0        1426826 2026-09-16 08:33:01.203202 2026-09-16 11:32:58.067     PHONE
# 1        1426825 2026-09-16 08:32:53.050035 2026-09-16 11:32:50.449     PHONE
# 2        1426824 2026-09-16 08:31:40.230850 2026-09-16 13:31:40.030     PHONE
# 3        1426823 2026-09-16 08:30:57.475055 2026-09-16 15:30:56.323     PHONE
# 4        1426822 2026-09-16 08:30:42.547585 2026-09-16 11:30:41.074     WATCH
# ...          ...                        ...                     ...       ...
# 1186807   240028 2023-07-27 13:15:28.000000 2023-07-27 07:15:25.918     PHONE
# 1186808   240027 2023-07-27 13:11:28.000000 2023-07-27 07:11:25.334     PHONE
# 1186809   240026 2023-07-26 23:50:06.000000 2023-07-26 15:22:41.211    LAPTOP
# 1186810   240025 2023-07-26 23:49:04.000000 2023-07-26 15:22:41.222    LAPTOP
# 1186811   240024 2023-07-26 23:43:23.000000 2023-07-26 15:22:41.233    LAPTOP
#
# ...

# %%
sales.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1186812 entries, 0 to 1186811
# Data columns (total 9 columns):
#  #   Column      Non-Null Count    Dtype
# ---  ------      --------------    -----
#  0   id          1186812 non-null  int64
#  1   created     1186812 non-null  datetime64[us]
#  2   cut_time    1186812 non-null  datetime64[us]
#  3   film_size   1186812 non-null  str
#  4   film_type   1186812 non-null  str
#  5   sale_type   1186812 non-null  str
#  6   time_zone   1186812 non-null  str
#  7   element_id  919061 non-null   float64
#  8   station_id  1186757 non-null  float64
# dtypes: datetime64[us](2), float64(2), int64(1), str(4)
# memory usage: 81.5 MB

# %% [markdown]
# ###

# %%
df1_html = sales['film_type'].value_counts().to_frame().to_html()
df2_html = sales['film_size'].value_counts().to_frame().to_html()
df3_html = sales['sale_type'].value_counts().to_frame().to_html()

display_html(f'<div style="display:flex; gap:20px;">{df1_html}{df2_html}{df3_html}</div>', raw=True)
# Out:
# <div style="display:flex; gap:20px;"><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>count</th>
#     </tr>
#     <tr>
#       <th>film_type</th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>MATE</th>
#       <td>641082</td>
#     </tr>
#     <tr>
#       <th>GLOSS</th>
#       <td>538093</td>
#     </tr>
#     <tr>
#       <th>SPY</th>
#       <td>5909</td>
#     </tr>
#     <tr>
#       <th>NONE</th>
#       <td>964</td>
#     </tr>
#     <tr>
#       <th>COLOR</th>
#       <td>764</td>
#     </tr>
#   </tbody>
# </table><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>count</th>
#     </tr>
#     <tr>
#       <th>film_size</th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>PHONE</th>
#       <td>1147628</td>
#     </tr>
#     <tr>
#       <th>WATCH</th>
#       <td>24044</td>
# ...

# %% [markdown]
# # Stations

# %%
stations = pd.read_csv('../../data/initial_data/ps_stations_initial.csv')

# %%
stations
# Out:
#         id                                            address  \
# 0        1  121601, Московская обл, Москва, Филевский б-р, 6
# 1        2  141310, Московская обл, Сергиево-Посадский р-н...
# 2        3  142600, Московская обл, Орехово-Зуево г, Якова...
# 3        4  142500, Московская обл, Павлово-Посадский р-н,...
# 4        5  141031, Московская обл, Мытищинский р-н, Алтуф...
# ...    ...                                                ...
# 4059  4063        г. Сочи, ул. Новая заря, дом 7, ТЦ МореМолл
# 4060  4064  г. Сочи, ул. Новая заря, дом 7, ТЦ МореМолл SA...
# 4061  4065   г. Котельники, 1-й Покровский проезд, д.1, ТЦ...
# 4062  4066  г. Краснодар, ул. Головатого, д.313,(пом.1-044...
# 4063  4067                        Норильск, ул. нансена, д.70
#
#                           code                     created        login  \
# 0                         CODE  2023-07-04 15:57:36.000000          ily
# 1                         L422  2023-07-04 15:58:42.000000     station1
# ...
